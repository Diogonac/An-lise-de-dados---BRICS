# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Diogo Nobre de Araujo Cintra

# %% [markdown]
# ## Introdução

# %% [markdown]
# Foi escolhido o grupo dos BRICS para ser estudado neste projeto.
# Países membros: Brasil, Rússia, China e África do Sul.
# O primeiro encontro dos presidentes de cada país ocorreu em 16 de junho de 2009 na Rússia, neste encontro a África do sul ainda não tinha entrado neste grupo político. Foi apenas em 24 de dezembro de 2010 que a África do Sul se tornou membro oficial do então conhecido país emergentes ou BRICS.
#
# A criação dos BRICS foi pelo fato de seus países membros terem índices semelhantes como crescimento industrial, PIB per capta e infraestrutura. Essas características de índices semelhantes entre esses países definiram o que conhecemos como país emergente. Em teoria fazer parte dos BRICS gerou alguns benefícios, como a criação do Novo Banco de Desenvolvimento do BRICS, por intermédio do banco, busca-se mobilizar recursos para incrementar o aporte de investimentos em infraestrutura e desenvolvimento sustentável nos países do BRICS e criação do Arranjo Contingente de Reservas, esse arranjo visa a respaldar os países membros, especificamente em eventuais cenários de crise em seus balanços de pagamentos.

# %% [markdown]
# ## Pergunta a ser respondida

# %% [markdown]
# Como a formação dos BRICS influenciou o crescimento dos países membros ?

# %% [markdown]
# ## Explicação da hipótese e mecanismo

# %% [markdown]
# ### Hipótese
# A criação dos BRICS foi pela semelhança econômica e social entre seus países membros. Dessa forma com a união desses países os crescimentos econômicos seriam semelhantes durante e após a formação do grupo.
#
# ### Mecanismo
# Caso ocorra o que foi proposto pela hipótese, o crescimento econômico dos países deve-se ao fato de acordos e benefícios gerados pelo o grupo como: a criação do Novo Banco de Desenvolvimento do BRICS, criação do Arranjo Contingente de Reservas e maior visibilidade para investimentos, uma vez que esses países estão emergindo na economia global, portanto são economicamente atraentes. Para verificar se isso ocorreu, será analisado como foram os crescimentos dos índices que caracterizam um país como emergente, antes e depois da formação do grupo.
#
# http://engemausp.submissao.com.br/17/anais/arquivos/66.pdf
# (Não soube colocar em ABNT)

# %% [markdown]
# ## Bases de dados usadas

# %% [markdown]
# https://www.gapminder.org/data/

# %%
#Importando as bibliotecas
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os
from numpy import arange
from numpy import percentile
import numpy as np

#Leitura da base de dados
GDPCAPTA = pd.read_excel('gdpcapta.xlsx')
IDH = pd.read_excel('idh.xlsx')
INTERNET = pd.read_excel('usuariosinternet.xlsx')
INDUSTRIA = pd.read_excel('industria.xlsx')
INVESTIMENTO = pd.read_excel('investimento.xlsx')
CRESCIMENTOGDP = pd.read_excel('crescimentoGDP.xlsx')

# %%
gdpcapta = GDPCAPTA.set_index('country')
BRICSGDP1 = gdpcapta.loc[['Brazil','Russia','India','China','South Africa','Chile','Ecuador']]
BRICSGDP2 = BRICSGDP1.transpose()
BRICSGDP3 = BRICSGDP2[BRICSGDP2.index >= 2000]
BRICSGDP4 = BRICSGDP3[BRICSGDP3.index <= 2015]
BRICSGDP4
# Out:
# country   Brazil   Russia   India   China  South Africa    Chile  Ecuador
# 2000      8780.0   6490.0   762.0  1770.0        5840.0   9470.0   3680.0
# 2001      8780.0   6850.0   785.0  1910.0        5910.0   9670.0   3760.0
# 2002      8920.0   7210.0   802.0  2070.0        6050.0   9850.0   3850.0
# 2003      8910.0   7770.0   850.0  2260.0        6140.0  10100.0   3890.0
# 2004      9310.0   8360.0   903.0  2470.0        6340.0  10800.0   4140.0
# 2005      9500.0   8930.0   971.0  2740.0        6600.0  11200.0   4290.0
# 2006      9760.0   9690.0  1040.0  3070.0        6890.0  11800.0   4400.0
# 2007     10200.0  10500.0  1130.0  3490.0        7190.0  12300.0   4420.0
# 2008     10700.0  11100.0  1160.0  3810.0        7340.0  12600.0   4620.0
# 2009     10500.0  10200.0  1240.0  4140.0        7150.0  12300.0   4570.0
# 2010     11200.0  10700.0  1350.0  4560.0        7280.0  12900.0   4660.0
# 2011     11600.0  11200.0  1420.0  4970.0        7420.0  13500.0   4940.0
# ...

# %%
idh = IDH.set_index('country')
BRICSIDH1 = idh.loc[['Brazil','Russia','India','China','South Africa','Chile','Ecuador']]
BRICSIDH2 = BRICSIDH1.transpose()
BRICSIDH3 = BRICSIDH2[BRICSIDH2.index >= 2000]
BRICSIDH4 = BRICSIDH3[BRICSIDH3.index <= 2015]
BRICSIDH4
# Out:
# country  Brazil  Russia  India  China  South Africa  Chile  Ecuador
# 2000      0.685   0.720  0.494  0.592         0.629  0.761    0.670
# 2001      0.692   0.727  0.499  0.600         0.620  0.768    0.675
# 2002      0.699   0.733  0.505  0.610         0.613  0.775    0.679
# 2003      0.695   0.741  0.518  0.622         0.611  0.781    0.682
# 2004      0.694   0.748  0.526  0.634         0.609  0.790    0.688
# 2005      0.698   0.754  0.536  0.646         0.609  0.796    0.693
# 2006      0.700   0.761  0.546  0.659         0.612  0.797    0.696
# 2007      0.704   0.769  0.556  0.672         0.616  0.804    0.698
# 2008      0.714   0.776  0.563  0.682         0.622  0.816    0.702
# 2009      0.716   0.773  0.569  0.691         0.630  0.815    0.703
# 2010      0.724   0.785  0.580  0.700         0.638  0.820    0.710
# 2011      0.730   0.792  0.590  0.703         0.644  0.826    0.717
# 2012      0.734   0.799  0.599  0.713         0.652  0.831    0.725
# ...

# %%
internet = INTERNET.set_index('country')
BRICSNET1 = internet.loc[['Brazil','Russia','India','China','South Africa','Chile','Ecuador']]
BRICSNET2 = BRICSNET1.transpose()
BRICSGDP3 = BRICSNET2[BRICSNET2.index >= 2000]
BRICSNET4 = BRICSGDP3[BRICSGDP3.index <= 2015]
BRICSNET4
# Out:
# country  Brazil  Russia   India  China  South Africa  Chile  Ecuador
# 2000       2.87    1.98   0.528   1.78          5.35   16.6     1.46
# 2001       4.53    2.94   0.660   2.64          6.35   19.1     2.67
# 2002       9.15    4.13   1.540   4.60          6.71   22.1     4.26
# 2003      13.20    8.30   1.690   6.20          7.01   25.5     4.46
# 2004      19.10   12.90   1.980   7.30          8.43   28.2     4.83
# 2005      21.00   15.20   2.390   8.52          7.49   31.2     5.99
# 2006      28.20   18.00   2.810  10.50          7.61   34.5     7.20
# 2007      30.90   24.70   3.950  16.00          8.07   35.9    10.80
# 2008      33.80   26.80   4.380  22.60          8.43   37.3    18.80
# 2009      39.20   29.00   5.120  28.90         10.00   41.6    24.60
# 2010      40.60   43.00   7.500  34.30         24.00   45.0    29.00
# 2011      45.70   49.00  10.100  38.30         34.00   52.2    31.40
# 2012      48.60   63.80  12.600  42.30         41.00   55.0    35.10
# ...

# %%
industria = INDUSTRIA.set_index('country')
BRICSIND1 = industria.loc[['Brazil','Russia','India','China','South Africa','Chile','Ecuador']]
BRICSIND2 = BRICSIND1.transpose()
BRICSIND3 = BRICSIND2[BRICSIND2.index >= 2000]
BRICSIND4 = BRICSIND3[BRICSIND3.index <= 2015]
BRICSIND4
# Out:
# country  Brazil  Russia  India  China  South Africa  Chile  Ecuador
# 2000       23.0    33.9   28.4   45.5          29.1   31.4     33.6
# 2001       22.6    31.8   27.6   44.8          29.6   31.8     29.0
# 2002       22.5    29.0   28.8   44.5          29.7   32.0     28.8
# 2003       23.1    28.7   28.6   45.6          28.0   33.4     28.0
# 2004       24.3    31.7   30.4   45.9          27.3   36.0     29.7
# 2005       24.2    32.6   30.7   47.0          27.1   36.9     31.5
# 2006       23.5    31.8   31.6   47.6          26.2   41.1     33.9
# 2007       23.1    31.2   31.7   46.9          26.5   39.9     34.5
# 2008       23.1    30.8   31.7   46.9          28.3   34.2     37.9
# 2009       21.9    29.3   31.1   45.9          27.6   34.4     32.4
# 2010       23.3    30.0   30.1   46.4          27.4   35.7     34.7
# 2011       23.1    29.3   30.2   46.4          26.9   34.7     37.6
# 2012       22.1    29.3   29.4   45.3          26.7   32.5     37.8
# ...

# %%
investimento = INVESTIMENTO.set_index('country')
BRICSINVEST1 = investimento.loc[['Brazil','Russia','India','China','South Africa','Chile','Ecuador']]
BRICSINVEST2 = BRICSINVEST1.transpose()
BRICSINVEST3 = BRICSINVEST2[BRICSINVEST2.index >= 2000]
BRICSINVEST4 = BRICSINVEST3[BRICSINVEST3.index <= 2015]
BRICSINVEST4
# Out:
# country  Brazil  Russia  India  China  South Africa  Chile  Ecuador
# 2000       18.9    18.7   27.0   34.4          16.4   22.1     21.3
# 2001       18.7    21.9   27.0   36.4          15.7   22.4     22.3
# 2002       17.4    20.1   27.6   37.1          16.3   22.3     23.7
# 2003       16.9    20.9   29.9   40.6          17.1   21.0     19.6
# 2004       17.9    20.9   36.6   42.9          18.5   19.8     20.2
# 2005       17.2    20.1   38.6   41.4          18.3   21.8     21.6
# 2006       17.8    21.2   39.7   40.9          20.2   20.8     22.5
# 2007       19.8    24.2   42.5   41.5          21.0   20.8     22.7
# 2008       21.6    25.5   38.2   43.3          23.2   26.8     26.4
# 2009       18.8    18.9   40.7   46.4          20.7   21.1     25.6
# 2010       21.8    22.6   40.7   47.6          19.5   23.1     28.0
# 2011       21.8    24.4   39.6   47.7          19.7   24.6     28.1
# 2012       21.4    24.5   38.3   47.2          20.0   26.4     27.8
# ...

# %%
crescimentogdp = CRESCIMENTOGDP.set_index('country')
CRESCIMENTOGDP1 = crescimentogdp.loc[['Brazil','Russia','India','China','South Africa','Chile','Ecuador']]
CRESCIMENTOGDP2 = CRESCIMENTOGDP1.transpose()
CRESCIMENTOGDP3 = CRESCIMENTOGDP2[CRESCIMENTOGDP2.index >= 2000]
CRESCIMENTOGDP4 = CRESCIMENTOGDP3[CRESCIMENTOGDP3.index <= 2015]
CRESCIMENTOGDP4
# Out:
# country  Brazil  Russia  India  China  South Africa  Chile  Ecuador
# 2000      4.520   10.10   4.28   5.63          4.37   4.54  -14.400
# 2001      0.984    5.19   5.66   6.95          3.01   3.43    5.220
# 2002      2.740    4.83   3.41  10.90          3.95   2.23    1.030
# 2003      1.050    7.46   8.36   8.21          3.23   3.96    4.160
# 2004      5.620    7.37   8.39  10.20          4.86   6.25    8.580
# 2005      2.760    6.60   7.97  10.10          5.52   6.36    5.220
# 2006      3.960    8.36   9.62  12.40          5.81   5.83    4.510
# 2007      6.090    8.68   9.22  11.20          5.68   5.20    2.240
# 2008      5.170    5.15   7.13   2.20          3.75   3.04    6.360
# 2009     -0.330   -7.80   5.07   7.50         -1.22  -0.91    0.997
# 2010      7.530    4.28  11.20   7.34          3.56   5.73    3.190
# 2011      2.730    4.57   7.75   5.56          2.89   5.92    7.870
# 2012      1.090    3.23   4.76   7.60          1.66   5.45    4.810
# ...

# %% [markdown]
# ### Corrigir legenda
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center

# %% [markdown]
# ### Comparação dos dados antes da formação do grupo

# %%
BRICSGDP = BRICSGDP4[BRICSGDP4.index <= 2010]
BRICSGDP.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("PIB per capta (US$)")
plt.title("PIB per capta nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSIDH = BRICSIDH4[BRICSIDH4.index <= 2010]
BRICSIDH.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("IDH")
plt.title("IDH nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSNET = BRICSNET4[BRICSNET4.index <= 2010]
BRICSNET.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("Individuos que usam internet (% de população)")
plt.title("Individuos que usam internet nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSIND = BRICSIND4[BRICSIND4.index <= 2010]
BRICSIND.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("Setor industrial (% do PIB)")
plt.title("Setor industrial nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSINVEST = BRICSINVEST4[BRICSINVEST4.index <= 2010]
BRICSINVEST.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("Investimento (% do PIB)")
plt.title("Investimento nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSCRESCIMENTOGDP = CRESCIMENTOGDP4[CRESCIMENTOGDP4.index <= 2010]
BRICSCRESCIMENTOGDP.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("Crescimento anual do PIB")
plt.title("rescimento anual do PIB nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %% [markdown]
# ### Comparação dos dados após a formação do grupo

# %%
BRICSGDP = BRICSGDP4[BRICSGDP4.index >= 2010]
BRICSGDP.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("PIB per capta (US$)")
plt.title("PIB per capta nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSIDH = BRICSIDH4[BRICSIDH4.index >= 2010]
BRICSIDH.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("IDH")
plt.title("IDH nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSNET = BRICSNET4[BRICSNET4.index >= 2010]
BRICSNET.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("Individuos que usam internet (% de população)")
plt.title("Individuos que usam internet nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSIND = BRICSIND4[BRICSIND4.index >= 2010]
BRICSIND.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("Setor industrial (% do PIB)")
plt.title("Setor industrial nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSINVEST = BRICSINVEST4[BRICSINVEST4.index >= 2010]
BRICSINVEST.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("Investimento (% do PIB)")
plt.title("Investimento nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %%
BRICSCRESCIMENTOGDP = CRESCIMENTOGDP4[CRESCIMENTOGDP4.index >= 2010]
BRICSCRESCIMENTOGDP.plot(subplots=False, figsize=(12, 6));
plt.legend(loc='upper left')
plt.xlabel("Anos")
plt.ylabel("Crescimento anual do PIB")
plt.title("Crescimento anual do PIB nos países Equador, Chile e membros dos BRICS entre 2000 e 2011")
plt.grid(True)

# %% [markdown]
# ### Características que definiram o que é um pais emergente e justificaram a formação dos BRICS

# %%
BRICSGDP5 = BRICSGDP4[BRICSGDP4.index == 2010]
#1350 - 11200
BRICSGDP6 = BRICSGDP5.transpose()

BRICSIDH5 = BRICSIDH4[BRICSIDH4.index == 2010]
#0.58 - 0.785
BRICSIDH6 = BRICSIDH5.transpose()

BRICSNET5 = BRICSNET4[BRICSNET4.index == 2010]
#7.5 - 43
BRICSNET6 = BRICSNET5.transpose()

BRICSIND5 = BRICSIND4[BRICSIND4.index == 2010]
#27.4 - 30.1
BRICSIND6 = BRICSIND5.transpose()

BRICSINVEST5 = BRICSINVEST4[BRICSINVEST4.index == 2010]
#19.5 - 47.6
BRICSINVEST6 = BRICSINVEST5.transpose()

BRICSCRESCIMENTOGDP5 = CRESCIMENTOGDP4[CRESCIMENTOGDP4.index == 2010]
#3.56 - 7.53
BRICSCRESCIMENTOGDP6 = BRICSCRESCIMENTOGDP5.transpose()

BRICS2010_1 = BRICSGDP6.join(BRICSIDH6, how='outer', lsuffix='_GDPC', rsuffix='_IDH')
BRICS2010_2 = BRICS2010_1.join(BRICSNET6, how='outer')
BRICS2010_2.rename(columns={2010:'2010_NET'}, inplace=True)
BRICS2010_3 = BRICS2010_2.join(BRICSIND6, how='outer')
BRICS2010_3.rename(columns={2010:'2010_IND'}, inplace=True)
BRICS2010_4 = BRICS2010_3.join(BRICSINVEST6, how='outer')
BRICS2010_4.rename(columns={2010:'2010_INVEST'}, inplace=True) 
BRICS2010_5 = BRICS2010_4.join(BRICSCRESCIMENTOGDP6, how='outer')
BRICS2010_5.rename(columns={2010:'2010_CRESCGDP'}, inplace=True)
SORTV = BRICS2010_5.sort_values(by="2010_CRESCGDP")
SORTV
# Out:
#               2010_GDPC  2010_IDH  2010_NET  2010_IND  2010_INVEST  \
# country
# Ecuador          4660.0     0.710      29.0      34.7         28.0
# South Africa     7280.0     0.638      24.0      27.4         19.5
# Russia          10700.0     0.785      43.0      30.0         22.6
# Chile           12900.0     0.820      45.0      35.7         23.1
# China            4560.0     0.700      34.3      46.4         47.6
# Brazil          11200.0     0.724      40.6      23.3         21.8
# India            1350.0     0.580       7.5      30.1         40.7
#
#               2010_CRESCGDP
# country
# Ecuador                3.19
# South Africa           3.56
# Russia                 4.28
# Chile                  5.73
# China                  7.34
# Brazil                 7.53
# India                 11.20

# %% [markdown]
# ### Verificando se os países que pertencem ao BRICS ainda podem ser considerados como emergente

# %%
BRICSGDP5 = BRICSGDP4[BRICSGDP4.index == 2015]
BRICSGDP6 = BRICSGDP5.transpose()

BRICSIDH5 = BRICSIDH4[BRICSIDH4.index == 2015]
BRICSIDH6 = BRICSIDH5.transpose()

BRICSNET5 = BRICSNET4[BRICSNET4.index == 2015]
BRICSNET6 = BRICSNET5.transpose()

BRICSIND5 = BRICSIND4[BRICSIND4.index == 2015]
BRICSIND6 = BRICSIND5.transpose()

BRICSINVEST5 = BRICSINVEST4[BRICSINVEST4.index == 2015]
BRICSINVEST6 = BRICSINVEST5.transpose()

BRICSCRESCIMENTOGDP5 = CRESCIMENTOGDP4[CRESCIMENTOGDP4.index == 2013]
BRICSCRESCIMENTOGDP6 = BRICSCRESCIMENTOGDP5.transpose()

BRICS2015_1 = BRICSGDP6.join(BRICSIDH6, how='outer', lsuffix='_GDPC', rsuffix='_IDH')
BRICS2015_2 = BRICS2015_1.join(BRICSNET6, how='outer')
BRICS2015_2.rename(columns={2015:'2015_NET'}, inplace=True)
BRICS2015_3 = BRICS2015_2.join(BRICSIND6, how='outer')
BRICS2015_3.rename(columns={2015:'2015_IND'}, inplace=True)
BRICS2015_4 = BRICS2015_3.join(BRICSINVEST6, how='outer')
BRICS2015_4.rename(columns={2015:'2015_INVEST'}, inplace=True) 
BRICS2015_5 = BRICS2015_4.join(BRICSCRESCIMENTOGDP6, how='outer')
BRICS2015_5.rename(columns={2013:'2013_CRESCGDP'}, inplace=True)

# %%
BRICS2015 = BRICS2015_5[(BRICS2015_5['2015_GDPC']>=1350) & (BRICS2015_5['2015_IDH'] >= 0.58) & (BRICS2015_5['2015_NET'] >= 7.5) & (BRICS2015_5['2015_IND'] >= 23.3) & (BRICS2015_5['2015_INVEST'] >= 19.5) & (BRICS2015_5['2013_CRESCGDP'] >= 3.56)]
BRICS2015
# Out:
#          2015_GDPC  2015_IDH  2015_NET  2015_IND  2015_INVEST  2013_CRESCGDP
# country
# India       1760.0     0.624      26.0      27.2         31.8           4.37
# China       6500.0     0.738      50.3      40.9         45.4           7.60
# Chile      14900.0     0.847      76.6      29.7         23.8           4.21
# Ecuador     5350.0     0.739      48.9      31.9         26.9           3.92

# %% [markdown]
# ### Verificando quais países então dentro da faixa "Emergente"

# %%
gdpcapta = GDPCAPTA.set_index('country')
BRICSgdp = gdpcapta.transpose()
BRICSgdp1 = BRICSgdp[BRICSgdp.index == 2010]
BRICSgdp2 = BRICSgdp1.transpose()

idh = IDH.set_index('country')
BRICSidh = idh.transpose()
BRICSidh1 = BRICSidh[BRICSidh.index == 2010]
BRICSidh2 = BRICSidh1.transpose()

internet = INTERNET.set_index('country')
BRICSnet = internet.transpose()
BRICSnet1 = BRICSnet[BRICSnet.index == 2010]
BRICSnet2 = BRICSnet1.transpose()

industria = INDUSTRIA.set_index('country')
BRICSind = industria.transpose()
BRICSind1 = BRICSind[BRICSind.index == 2010]
BRICSind2 = BRICSind1.transpose()

investimento = INVESTIMENTO.set_index('country')
BRICSinvet = investimento.transpose()
BRICSinvet1 = BRICSinvet[BRICSinvet.index == 2010]
BRICSinvet2 = BRICSinvet1.transpose()

crescimentogdp = CRESCIMENTOGDP.set_index('country')
BRICScrescimentogdp = crescimentogdp.transpose()
BRICScrescimentogdp1 = BRICScrescimentogdp[BRICScrescimentogdp.index == 2010]
BRICScrescimentogdp2 = BRICScrescimentogdp1.transpose()

# %%
allj1 = BRICSgdp2.join(BRICSidh2, how='outer', lsuffix='_GDPC', rsuffix='_IDH')
allj2 = allj1.join(BRICSnet2, how='outer')
allj2.rename(columns={2010:'2010_NET'}, inplace=True)
allj3 = allj2.join(BRICSind2, how='outer')
allj3.rename(columns={2010:'2010_IND'}, inplace=True)
allj4 = allj3.join(BRICSinvet2, how='outer')
allj4.rename(columns={2010:'2010_INVEST'}, inplace=True) 
allj5 = allj4.join(BRICScrescimentogdp2, how='outer')
allj5.rename(columns={2010:'2010_CRESCGDP'}, inplace=True)
#allj4[allj4['2010_GDPC'] > 10000]
EMERGENTES1 = allj5[(allj5['2010_GDPC']>=1350) & (allj5['2010_IDH'] >= 0.58) & (allj5['2010_NET'] >= 7.5) & (allj5['2010_IND'] >= 23.3) & (allj5['2010_INVEST'] >= 19.5) & (allj5['2010_CRESCGDP'] >= 3.56)]
EMERGENTES2 = EMERGENTES1[(EMERGENTES1['2010_GDPC'] <= 11200) & (EMERGENTES1['2010_IDH'] <= 0.785) & (EMERGENTES1['2010_NET'] <= 43) & (EMERGENTES1['2010_IND'] <= 46.4) & (EMERGENTES1['2010_INVEST'] <= 47.6) & (EMERGENTES1['2010_CRESCGDP'] <= 11.2)]
EMERGENTES2
# Out:
#                     2010_GDPC  2010_IDH  2010_NET  2010_IND  2010_INVEST  \
# country
# Brazil                11200.0     0.724      40.6      23.3         21.8
# China                  4560.0     0.700      34.3      46.4         47.6
# Colombia               6250.0     0.700      36.5      32.0         22.1
# Dominican Republic     5450.0     0.703      31.4      25.8         26.4
# Egypt                  2600.0     0.671      21.6      35.8         19.5
# Guyana                 3040.0     0.624      29.9      31.1         25.2
# Honduras               1930.0     0.611      11.1      25.6         21.9
# India                  1350.0     0.580       7.5      30.1         40.7
# Indonesia              3110.0     0.662      10.9      42.8         32.9
# Iran                   6530.0     0.745      15.9      44.2         40.3
# Kazakhstan             9070.0     0.766      31.6      40.6         25.4
# Mexico                 9020.0     0.745      31.1      32.4         22.8
# ...

# %% [markdown]
# ## Análise de dados

# %% [markdown]
# Insira abaixo uma análise de dados tratada para ter maior clareza.
#
# Lembre-se de que, além deste arquivo principal, você precisa entregar um ou mais *notebooks* mais brutos com todas as tentativas que fez e que não deram certo .
#
# **Não inclua dados ou gráficos sem motivação nem interpretação** - sempre que fizer uma análise, plot ou tablea, diga qual sua intenção. Logo após a apresentação diga qual conclusão específica ou interpretação você tira daquela análise

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Responda à pergunta, argumento da melhor forma possível com base nos dados
